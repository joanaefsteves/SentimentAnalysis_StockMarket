# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## <center> <b> Stock Sentiment </center>
# ## <center> Predicting market behavior from tweets </center> <br>
# ##  <center> <b> EDA </center> <br>
# ## <center> Spring Semester 2024-2025 <center>
#
# <center> Group 35: <center>
# <center>Joana Esteves, 20240746 <br><center>
# <center>José Cavaco, 20240513 <br><center>
# <center> Leonardo Di Caterina 20240485<br><center>
# <center>Matilde Miguel, 20240549 <br><center>
# <center>Rita Serra, 20240515 <br><center>
#
# <div>

# %% [markdown]
# **Table of Contents**
# - [1. Import the needed Libraries](#importlibraries)
# - [2. Import Dataset](#importdataset)
# - [3. Exploratory Analysis](#section_3)

# %% [markdown]
# <a class="anchor" id="importlibraries">
#
# # 1. Import the needed Libraries
#
# </a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import re
from langdetect import detect
import emoji

# %% [markdown]
# <a class="anchor" id="importdataset">
#
# # 2. Import the dataset
#
# </a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# base_path= '/content/drive/MyDrive/TM Project/'

base_path = "Data/"

# %%
train_df = pd.read_csv(base_path+ 'train.csv')
test_df = pd.read_csv(base_path+ 'test.csv')

# %%
train_df.head()
# Out:
#                                                 text  label
# 0  $BYND - JPMorgan reels in expectations on Beyo...      0
# 1  $CCL $RCL - Nomura points to bookings weakness...      0
# 2  $CX - Cemex cut at Credit Suisse, J.P. Morgan ...      0
# 3  $ESS: BTIG Research cuts to Neutral https://t....      0
# 4  $FNKO - Funko slides after Piper Jaffray PT cu...      0

# %% [markdown]
# <a class="anchor" id="section_3">
#
# # 3. Exploratory Analysis
#
# </a>

# %%
train_df.shape
# Out:
# (9543, 2)

# %% [markdown]
# ### Missing Values

# %%
train_df.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# There are no missing values ​​in the train data.

# %% [markdown]
# ### Target Exploration

# %% [markdown]
# Check unique values for the target labels:

# %%
train_df['label'].unique()
# Out:
# array([0, 1, 2])

# %%
label_distribution= train_df['label'].value_counts()
label_distribution
# Out:
# label
# 2    6178
# 1    1923
# 0    1442
# Name: count, dtype: int64

# %%
# Compute counts and proportions
label_counts = train_df['label'].value_counts().sort_index()
label_props = train_df['label'].value_counts(normalize=True).sort_index() * 100

# Plot
plt.figure(figsize=(7, 6))
bars = plt.bar(label_counts.index.astype(str), label_counts.values)

# Add text labels (value + %)
for bar, count, prop in zip(bars, label_counts.values, label_props.values):
    label = f"{count} ({prop:.1f}%)"
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100, label,
             ha='center', va='bottom', fontsize=10)

# Labels and title
plt.title('Distribution of Target Values')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# The dataset is imbalanced, with class 2 representing the majority of the data.

# %% [markdown]
# ### Text Exploration

# %%
train_df["char_len"] = train_df["text"].str.len()
train_df['word_count']  = train_df['text'].apply(lambda x: len(str(x).split()))

# %%
train_df.head()
# Out:
#                                                 text  label  word_count  \
# 0  $BYND - JPMorgan reels in expectations on Beyo...      0          10
# 1  $CCL $RCL - Nomura points to bookings weakness...      0          14
# 2  $CX - Cemex cut at Credit Suisse, J.P. Morgan ...      0          14
# 3  $ESS: BTIG Research cuts to Neutral https://t....      0           7
# 4  $FNKO - Funko slides after Piper Jaffray PT cu...      0          10
#
#    char_len
# 0        77
# 1       102
# 2        94
# 3        59
# 4        71

# %%
example = train_df['text'].iloc[0]
print(example)
print("Word:", len(example.split()))
# Out:
# $BYND - JPMorgan reels in expectations on Beyond Meat https://t.co/bd0xbFGjkT
# Word: 10

# %%
total = train_df['word_count'].sum()
print(total)
# Out:
# 116218

# %%
train_df[['word_count','char_len']].describe()
# Out:
#         word_count     char_len
# count  9543.000000  9543.000000
# mean     12.178351    85.816934
# std       4.665599    35.097229
# min       1.000000     2.000000
# 25%       9.000000    58.000000
# 50%      11.000000    79.000000
# 75%      15.000000   120.000000
# max      32.000000   190.000000

# %%
#Plot distribution of text length
sns.histplot(train_df['word_count'], bins=20)
plt.title("Distribution of Text Lengths (raw text)")
plt.xlabel("Length of text")
plt.ylabel("Frequency")
plt.show()

# %%
all_words = ' '.join(train_df['text']).split()
freq = pd.Series(all_words).value_counts()
freq.sort_values(ascending=False)[0:10]
# Out:
# to     2332
# the    1820
# of     1464
# -      1390
# in     1361
# on     1136
# for    1032
# a       970
# and     898
# The     663
# Name: count, dtype: int64

# %%
x_labels = freq.index[0:10]
values = freq[:10]
plt.bar(x_labels, values, align='center', alpha=0.5)
plt.xticks(x_labels)
plt.ylabel('Frequencies')
plt.title('Words')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a word cloud from the raw text
raw_text = ' '.join(train_df['text'].fillna('')).lower()
raw_wc = WordCloud(width=800, height=400, background_color='white').generate(raw_text)
plt.imshow(raw_wc, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud (Raw Text)')
plt.show()

# %%
train_df["has_ticker"] = train_df["text"].str.contains(r"\$\w+")
train_df["has_link"] = train_df["text"].str.contains("https")
train_df["has_mention"] = train_df["text"].str.contains("@")
train_df["has_hashtag"] = train_df["text"].str.contains("#")

# %%
bool_variable=["has_ticker","has_link","has_mention","has_hashtag"]
for var in bool_variable:
  print(train_df[var].value_counts())
# Out:
# has_ticker
# False    7261
# True     2282
# Name: count, dtype: int64
# has_link
# False    5073
# True     4470
# Name: count, dtype: int64
# has_mention
# False    9249
# True      294
# Name: count, dtype: int64
# has_hashtag
# False    8647
# True      896
# Name: count, dtype: int64

# %% [markdown]
# ### Text Length Distribution per Sentiment

# %%
# Number of words
sns.boxplot(x="label", y="word_count", data=train_df)
plt.title("Distribution of word count per sentiment")
plt.xticks([0,1,2], ["Bearish (0)", "Bullish (1)", "Neutral (2)"])
plt.show()

# Number of characters
sns.boxplot(x="label", y="char_len", data=train_df)
plt.title("Distribution of character count per sentiment")
plt.xticks([0,1,2], ["Bearish (0)", "Bullish (1)", "Neutral (2)"])
plt.show()

# %% [markdown]
# ### Patterns

# %%
email_patterns =  re.compile(r'\b[\w.-]+?@\w+?\.\w+?\b')
cost_pattern = re.compile(r'[$€£]\d+(?:[\.,]?\d+)?')
url_pattern = re.compile(r'http\S+|www\S+|https\S+')
hashtag_pattern = re.compile(r'#\w+')
user_tag_pattern = re.compile(r'@\w+')
ticker_pattern = re.compile(r'\$[A-Z]{1,6}\b')
elongation_word_pattern = re.compile(r"\b[a-zA-Z]*([a-zA-Z])\1{2,}")

# %%
def check_patterns(df, text_col='text'):
    patterns = {
        'EMAIL': email_patterns,
        'COST': cost_pattern,
        'URL': url_pattern,
        'HASHTAG': hashtag_pattern,
        'USER': user_tag_pattern,
        # dollar sign followed by 1 to 6 capital letters
        'TICKER': ticker_pattern,
        # Extra chars (only letters)
        'ELONG': elongation_word_pattern,
    }

    result = {}
    for label, pattern in patterns.items():
        result[label] = df[text_col].apply(lambda x: bool(re.search(pattern, str(x)))).any()
    return result

# %%
patterns = check_patterns(train_df, text_col='text') 
print(patterns)
# Out:
# {'EMAIL': np.False_, 'COST': np.True_, 'URL': np.True_, 'HASHTAG': np.True_, 'USER': np.True_, 'TICKER': np.True_, 'ELONG': np.True_}

# %%
def get_elongated_words(text):
    return [match.group(0) for match in elongation_word_pattern.finditer(str(text))]

elongated_words = train_df["text"].apply(get_elongated_words).explode().dropna().unique().tolist()

print("Elongated words found:")
print(elongated_words)
# Out:
# Elongated words found:
# ['BBB', 'RRR', 'PPP', 'Coffeee', 'III', 'rrr', 'GGG', 'StWqqq', 'Dolll', 'QQQ', 'xpAujlll', 'SSS', 'Sweeeeeeeeeetttttt', 'AAA', 'CCC', 'xJJJJ', 'TQQQ', 'DOOO', 'shhh', 'YoBeee']

# %% [markdown]
# - Most cases detected are not words elongations, so we may not consider this pattern in preprocessing.

# %%
def get_user_tags(text):
    return [match.group(0) for match in user_tag_pattern.finditer(str(text))]

user_tags = train_df["text"].apply(get_user_tags).explode().dropna().unique().tolist()

print("User tags found:")
print(user_tags)
# Out:
# User tags found:
# ['@WorldBank', '@TimLampkin', '@higherpurposeco', '@flacqua', '@bcheungz', '@CNBCAfrica', '@FedFRASER', '@mdbaccardax', '@CMEGroup', '@bopinion', '@USTreasury', '@RichMiller28', '@EdLudlow', '@YahooFinance', '@heidi_chung', '@BlackBox_Team', '@benzinga', '@stitchfix', '@luxury', '@realDonaldTrump', '@JimCramer', '@Nasdaq', '@ElonMusk', '@brianreports', '@readDanwrite', '@BW', '@business', '@bridgetteAwebb', '@MakerDAO', '@rickjnewman', '@CNBCMakeIt', '@SibileTV', '@TradingNation', '@TonyTheStreet', '@MaleehaMBCC', '@Street_Insider', '@OscarWGrut', '@GitaGopinath', '@BreakingViews', '@InvescoUS', '@NewConstructs', '@Jefferies', '@davidfickling', '@IATA', '@AnjKhem', '@suntrust', '@WellsFargo', '@GiteshPandya', '@SamRo', '@GoldmanSachs', '@UN_Women', '@justbobbibrown', '@Giants', '@RobinhoodSnacks', '@Discover_Pods', '@aztecs99', '@bcope51', '@CNBCselect', '@Coldplay', '@RevShark', '@Roku', '@SecAzar', '@SussexUni', '@Sweetgreen', '@HeyTammyBruce', '@MikeCaymanTrades', '@RobInTheBlack', '@SpeakerPelosi', '@TicToc', '@tictoc', '@telefenoticias', '@teleSUR_Chile', '@PaoladrateleSUR', '@monlaferte', '@inddhh', '@mbachelet', '@MadMoneyOnCNBC', '@antonioguterres', '@GitHub', '@sussexuni', '@acorns', '@Christiesinc', '@OfficialZSL', '@shuli_ren', '@robertshrimsley', '@Jason_Buck', '@Deray', '@DanielHowley', '@GretaThunberg', '@ChristineRomans', '@PACEUniversity', '@NasdaqCorpGov', '@MIT', '@Brixmor', '@jacknicklaus', '@suzeormanshow', '@eaze', '@BobbyBerk', '@melodyhahm', '@tom_belger', '@adrianambells', '@danielhowley', '@EdwardsLifesci', '@justcapital_', '@LinkedInEcon', '@KPMG', '@RealSportsHBO', '@scottgamm', '@spyjared', '@PwC', '@candacecbure', '@NadavKidro', '@serwer', '@Melodyhahm', '@jemaswad', '@JessicaASmith8', '@UBS', '@garnishgather', '@cb_childers', '@dartmouth', '@mathewfras', '@Ejcacciatore', '@VoyaInvestments', '@denitsa_tsekova', '@danariely', '@JohnFollain', '@sarahhalzack', '@VerizonBusiness', '@mingtsai', '@Sarge986', '@RealMoney', '@EelectricMiguel', '@TNAquarium', '@fatjoe', '@jonfortt', '@adenatfriedman', '@MaxZahn_', '@BrianSozzi', '@BloombergTV', '@Tesla', '@FoxBusiness', '@dsinghx', '@rogerfederer', '@sdonnan', '@WmMorrowBooks', '@Pitbull', '@JeffCooperLive', '@ScottSaloway', '@TSeries', '@WilliamTurton', '@Jess_Shankleman', '@CateyHill', '@NYCHealthCommr', '@DominionEnergy', '@jiatolentino', '@_DionneWarwick', '@byKatherineRoss', '@KGeorgieva', '@PoliticoRyan', '@DoubleTGolle', '@ZSchneeweiss', '@Noahpinion', '@MargaretAtwood', '@taffyakner', '@edmundlee', '@robotodd', '@GreteSuarez', '@FatboySlim', '@Infosys', '@NandanNilekani', '@datadoghq', '@guardian', '@fournierwire', '@KansasCityFed', '@inesreports', '@emily_mcck', '@carlquintanilla', '@conmedcorporation', '@Generac', '@AOC', '@ByDonkeys', '@BernieSanders', '@kilmeade', '@foxandfriends', '@jasoninthehouse', '@FoxNews', '@nytimes', '@ewolffmann', '@alexisTVNews', '@karlbykarlsmith', '@martinwolf_', '@MarketSmith', '@InvestorsBusinessDaily', '@here', '@AlphaStockNews1', '@ArgusResearch', '@cfraresearch', '@rbradthomas', '@1', '@simbatrading', '@ljganz', '@millennial_investing_', '@tparekh', '@MikeBloomberg', '@eWhispers', '@Benzinga', '@EdwardJones', '@ViacomCBS', '@ParamountPics', '@MTV', '@Nickelodeon', '@ComedyCentral', '@BET']

# %%
def get_costs(text):
    return [match.group(0) for match in cost_pattern.finditer(str(text))]

costs = train_df["text"].apply(get_costs).explode().dropna().unique().tolist()

print("Costs found:")
print(costs)
# Out:
# Costs found:
# ['$35', '$39', '$97', '$100', '$1.00', '$1.75', '$86', '$172', '$50', '$65', '$80', '$105', '$8', '$12', '$9.00', '$12.25', '$10', '$25', '$30', '$32', '$13', '$16', '$34', '$5', '$6', '$237', '$240', '$48', '$52', '$53', '$20', '$28', '$33', '$58', '$70', '$7', '$11', '$14', '$9', '$405', '$415', '$135', '$124', '$133', '$3', '$90', '$95', '$57', '$79', '$315', '$290', '$318', '$310', '$36', '$305', '$54', '$4', '$265', '$235', '$330', '$300', '$255', '$203', '$87', '$84', '$40', '$24', '$49', '$38', '$56', '$392', '$320', '$410', '$350', '$427', '$406', '$23.50', '$120', '$111', '$47', '$43', '$130', '$103', '$72', '$85', '$46', '$2.25', '$2.00', '$104', '$82', '$41', '$51', '$238', '$202', '$55', '$168', '$163', '$325', '$115', '$110', '$60', '$117', '$1', '$225', '$363', '$319', '$62', '$165', '$280', '$260', '$222', '$107', '$99', '$113', '$106', '$155', '$259', '$41.50', '$39.50', '$6.00', '$5.50', '$139', '$128', '$23', '$22', '$26', '$75', '$322', '$274', '$159', '$150', '$42', '$160', '$157', '$94', '$125', '$122', '$36.50', '$34.50', '$3.50', '$45', '$21', '$18', '$338', '$303', '$248', '$143', '$141', '$64', '$27', '$10.60', '$500', '$2.55', '$50.08', '$2.345', '$66', '$38.2', '$13.6', '$600', '$1.5', '$72.8', '$4.07', '$45.55', '$70.2', '$745', '$49.05', '$93.5', '$805', '$3.9', '€176.5', '$3.555', '$200', '$300,000', '$250', '$4.5', '$425', '$12.6', '$731', '$12.5', '$1.45', '$50,000', '$450', '$1.2', '$454', '$935', '$0.1975', '$12.9', '$13.4', '$25,000', '$127', '$12.7', '€901', '$656', '$37', '$67', '$400', '$43,000', '$1.3', '$5.6', '€975', '$7.0', '$33.1', '$380', '$603.5', '$3.1', '$15.15', '$23.7', '$296', '$3.3', '$50,623', '$1.325', '$2.9', '$420', '$92', '$13.5', '$176', '$140', '$184', '$0.5985', '$3.6471', '$6.9', '$3.5', '$700', '$600.0', '$1.25', '$5.5', '$230', '$11.0', '$4.3', '$2', '$2.1', '$41.7', '$6.2', '$1.925', '$0.30', '$0.28', '$20.00', '$0.46', '$0.275', '$0.0655', '$0.50', '$0.10', '$0.57', '$0.12', '$0.285', '$0.16', '$0.0215', '$0.17', '$0.05902', '$0.0850', '$0.0840', '$0.039', '$0.14525', '$0.0717', '$0.07922', '$0.0709', '$0.135', '$0.05', '$0.25', '$1.05', '$0.175', '$0.24', '$0.485', '$0.09', '$0.02', '$0.31', '$0.33', '$0.40', '$0.955', '$0.058', '$0.2025', '$0.47', '$0.06', '$4.25', '$0.065', '$0.1125', '$0.325', '$5.35', '$0.11642', '$0.465', '$0.27', '$0.22', '$0.14', '$3.30', '$0.2031', '$1.06', '$0.85', '$0.08', '$0.21', '$0.4175', '$0.07417', '$0.0621', '$1.08', '$0.365625', '$0.328125', '$0.367188', '$0.4025', '$0.075', '$0.48', '$0.0839', '$0.49', '$0.7625', '$3.35', '$0.15', '$0.235', '$0.20', '$0.125', '$0.67', '$0.145', '$1.10', '$0.0488', '$0.61', '$0.036724557', '$0.0117', '$0.044', '$0.0445', '$0.049', '$0.095', '$0.155', '$0.23', '$0.04', '$0.36', '$0.038987', '$0.0373', '$0.01', '$0.37', '$0.165', '$0.42', '$0.3219', '$0.025', '$0.19', '$0.5125', '$0.26', '$1.80', '$55.12', '$55.21', '$1.84', '$50.46', '$23.63', '$2.289', '$60.43', '$63', '$51.84', '$62.56', '$0.13', '$0.66', '$9.30', '$0.11', '$1.42', '$1.50', '$1.44', '$1.48', '$1.4', '$1.52', '$1.55', '$0.03', '$1.38', '$1.02', '$3.22', '$3.32', '$4.75', '$4.95', '$5.15', '$5.45', '$5.173', '$5.404', '$5.321', '$628.8', '$632.2', '$1.04', '$0.75', '$0.18', '$0.34', '$0.62', '$0.07', '$52.50', '$1.88', '$1.23', '$1.27', '$1.26', '$430', '$428', '$420.4', '$1.82', '$1.81', '$299.4', '$282.1', '$4.62', '$4.01', '$4.35', '€0.02', '$1.32', '$0.056', '$3.14', '$3.18', '$508.4', '$502.7', '$502', '$7.713', '$7.499', '$7.661', '$18.67', '$17.82', '$18.45', '$10.45', '$9.83', '$10.32', '$1.66', '$1.58', '$1.63', '$498', '$10.82', '$10.19', '$11.06', '$1.69', '$1.56', '$0.38', '$0.43', '$5.77', '$5.79', '$2.12', '$9.45', '$6.12', '$42.2', '$40.5', '$42.5', '$35.8', '$10.2', '$2.57', '$2.77', '$2.85', '$3.05', '$1.47', '$2.63', '$583', '$2.95', '$1.34', '$92.9', '$304.0', '$399.4', '$5.60', '$1.22', '$1.21', '€0.06', '$3.84', '$3.29', '$1.0965', '$2.3', '$453', '$1500', '$1.35', '$1.1003', '$1.1080', '$1.2947', '$11.8', '$ ...

# %%
def get_urls(text):
    return [match.group(0) for match in url_pattern.finditer(str(text))]

urls = train_df["text"].apply(get_urls).explode().dropna().unique().tolist()

print("Urls found:")
print(urls)
# Out:
# Urls found:
# ['https://t.co/bd0xbFGjkT', 'https://t.co/yGjpT2ReD3', 'https://t.co/KN1g4AWFIb', 'https://t.co/MCyfTsXc2N', 'https://t.co/z37IJmCQzB', 'https://t.co/XKcPDilIuU', 'https://t.co/tdUfG5HbXy', 'https://t.co/7Fv1ZiFZBS', 'https://t.co/rlnEwzlzzS', 'https://t.co/LurHBEadeU', 'https://t.co/wU5P2i8WBU', 'https://t.co/YsvsMSQRIb', 'https://t.co/8yrbwAjLKG', 'https://t.co/mJ1eSrsFXJ', 'https://t.co/0BFQy4ZU6W', 'https://t.co/Ul2S6XNXw8', 'https://t.co/qlFxZuhkrt', 'https://t.co/PdPkgLk0FQ', 'https://t.co/eoq7Lchtk4', 'https://t.co/WrQXTC38nB', 'https://t.co/Ky3d8DxnjX', 'https://t.co/NKYQgy2o3J', 'https://t.co/APfxEqSSRF', 'https://t.co/hsWCvJb1Ct', 'https://t.co/PlbSaE1Nc2', 'https://t.co/InJKourtW3', 'https://t.co/NGkYTADOSt', 'https://t.co/NhiYwphBQd', 'https://t.co/jMJ3N4A06T', 'https://t.co/vuNpYwRDSg', 'https://t.co/niUwYR5YUD', 'https://t.co/WnCksfl1gX', 'https://t.co/MfhnyZe593', 'https://t.co/1adfDkHeaw', 'https://t.co/d4TGqrNi7Y', 'https://t.co/pyARTEahWH', 'https://t.co/uNK2xzGQuq', 'https://t.co/taTMaip1uM', 'https://t.co/BDnqOJSFq5', 'https://t.co/Swtzl0mjnF', 'https://t.co/Sp4I2ehAVw', 'https://t.co/ekx4f6aqIK', 'https://t.co/TBgKmZH6pM', 'https://t.co/65zGfs82xI', 'https://t.co/xWbLXU1yOY', 'https://t.co/6z62FXsUom', 'https://t.co/l3m78pJzrW', 'https://t.co/8MMo05uiM6', 'https://t.co/rfNcO3sw2k', 'https://t.co/8k4l0c5x89', 'https://t.co/TekdZS48et', 'https://t.co/Ve7bTreR7Y', 'https://t.co/1xx084l36h', 'https://t.co/4fx811IVG5', 'https://t.co/1s0WRleA2n', 'https://t.co/2blCalNe9P', 'https://t.co/8go8ZhMvdc', 'https://t.co/emLga0CBm1', 'https://t.co/BJhXfQuRTd', 'https://t.co/NVjiO6Brwb', 'https://t.co/9gTGxKbSGj', 'https://t.co/QbgS6IQXRt', 'https://t.co/swy7IVNnQE', 'https://t.co/qmfAPKICdp', 'https://t.co/23HWM60K7q', 'https://t.co/jXZNb22Cwb', 'https://t.co/9TLXzYZjUs', 'https://t.co/VSzHLqLBgE', 'https://t.co/KfPaweOVgo', 'https://t.co/kEKxNfJEgZ', 'https://t.co/5hasUcG1ON', 'https://t.co/a5WT4knuVf', 'https://t.co/hjXizuPs7Z', 'https://t.co/xST0VP6IgS', 'https://t.co/jzxbhHJwOu', 'https://t.co/xscOdKUhfo', 'https://t.co/p8lniQQTZt', 'https://t.co/VsHuUI8mgj', 'https://t.co/pWzgfDXDm3', 'https://t.co/OAXfDtrtAk', 'https://t.co/nktomiS4jW', 'https://t.co/A5r5dgKIhX', 'https://t.co/Gwahc0Sc0F', 'https://t.co/a5XeRxCEVl', 'https://t.co/hDvBAwFDeG', 'https://t.co/wnLxXP4sHu', 'https://t.co/QwCihVGWly', 'https://t.co/ZRbeFgfAdo', 'https://t.co/AjGZqiRl5b', 'https://t.co/i1jKKq9kNi', 'https://t.co/4Ug71D7IN6', 'https://t.co/4FrdSvMV8T', 'https://t.co/YaN7qVv5aq', 'https://t.co/zn3oEbjuL7', 'https://t.co/11FIumVTXC', 'https://t.co/gMBiUS6z7J', 'https://t.co/UjqUoGk3L9', 'https://t.co/OVGpDhlZOb', 'https://t.co/fuN3T0obd5', 'https://t.co/elfM7nRACS', 'https://t.co/WR3CYfD3hy', 'https://t.co/8Ko2fxHj7W', 'https://t.co/8rGhax4y8C', 'https://t.co/Ed0jVBpmhZ', 'https://t.co/cCUifiy1YG', 'https://t.co/pjXZLMl9Jf', 'https://t.co/jdypDu2LhY', 'https://t.co/ZHKV5YcU5L', 'https://t.co/gB2rZSnrcF', 'https://t.co/46F3sPCsXW', 'https://t.co/Hn3cXkJQhp', 'https://t.co/nQOWWsXkh7', 'https://t.co/tILUoEQkYC', 'https://t.co/IO6JFnTMWX', 'https://t.co/bDhYKopjCM', 'https://t.co/08TD4PqNna', 'https://t.co/5ct4SutY3Q', 'https://t.co/mBzYyHmCrW', 'https://t.co/ioNcxm5GzF', 'https://t.co/7PFLksQXJP', 'https://t.co/FrLrivydji', 'https://t.co/OCCUO9DX7c', 'https://t.co/0rRXf0aqLC', 'https://t.co/4nTXbSxrHN', 'https://t.co/VMcZWh4sop', 'https://t.co/3SLpGWc3KL', 'https://t.co/JkbAPjX6Yv', 'https://t.co/GFYiDHmP2U', 'https://t.co/7O2gkIusAO', 'https://t.co/xEMWn1vjAO', 'https://t.co/yQBoa6mTqi', 'https://t.co/UhzEj1icQ3', 'https://t.co/aUORNC7SON', 'https://t.co/rrzy3Yv56J', 'https://t.co/rlYmLpiGKA', 'https://t.co/9v3IP9D10o', 'https://t.co/jtZoHHCmeB', 'https://t.co/pbo30sSQ9Z', 'https://t.co/3R4DyktUJ0', 'https://t.co/pUobuzSFBj', 'https://t.co/ZTGR5dNCBo', 'https://t.co/YrbmCS9ZX9', 'https://t.co/UCjDmDNwoP', 'https://t.co/Rua86ZJmMO', 'https://t.co/3WQX0rnURD', 'https://t.co/YAnONEz11p', 'https://t.co/xmvuhapL8v', 'https://t.co/lOpNKjwNeJ', 'ht ...

# %%
def get_hashtags(text):
    return [match.group(0) for match in hashtag_pattern.finditer(str(text))]

hashtags = train_df["text"].apply(get_hashtags).explode().dropna().unique().tolist()

print("Hashtags found:")
print(hashtags)
# Out:
# Hashtags found:
# ['#Samp', '#economy', '#MarketScreener', '#BankofNovaScotia', '#FedReport', '#IMFBlog', '#G20', '#markets', '#investing', '#MustRead', '#Survey', '#CESEE', '#FreeZeroHedge', '#taux', '#BankofIreland', '#Stock', '#BankofJamaica', '#BankofJapan', '#BankofQueensland', '#business', '#trading', '#currency', '#OpportunityOccupations', '#collegedegree', '#stocks', '#HellenicExchanges', '#Somalia', '#MENA', '#Tunisia', '#FOMC', '#FedData', '#Parkmead', '#stockmarket', '#SaudiArabianMonetaryAgency', '#COVID19', '#NorthMacedonia', '#Airbus', '#FinnairOyj', '#IFA', '#Nutrien', '#Cybertruck', '#Unilever', '#AmaniGold', '#engage', '#ElonMusk', '#baron', '#finance', '#AbbVie', '#ActinogenMedical', '#ADXEnergy', '#AgatiFund', '#AlacerGold', '#AllianceTrust', '#AmericanAirlines', '#AngloAustralianResourcesNL', '#ArborRealtyTrust', '#ArmourEnergy', '#AssetOwl', '#AtlasArteria', '#AudaxRenovablesSA', '#AUDI', '#AudioCodes', '#AuroraCannabis', '#AusQuest', '#AustarGold', '#Aveo', '#AvitaMedical', '#BaxterInternational', '#BlackRock', '#BlackRockFrontiersInvestmentTrust', '#BrooksideEnergy', '#Carpetright', '#CFOAM', '#ChinaFeihe', '#ClipperLogistics', '#Clover', '#guidance', '#CobaltBlue', '#Cobham', '#Cofinimmo', '#CozironResources', '#CrowdMedia', '#StBarbara', '#CynataTherapeutics', '#StockoftheDay', '#Dimerix', '#DuxtonBroadacreFarms', '#EliLillyand', '#elumeo', '#EncounterResources', '#EstreAmbiental', '#Exelon', '#Shinvest', '#FatProphetsPty', '#FDM', '#FieraMilano', '#FletcherBuilding', '#ForagerFundsManagementPty', '#JEOL', '#FrenchConnection', '#GalileoMining', '#GalpEnergiaSGPS', '#Garmin', '#GlobalInvestments', '#GoldONResources', '#Grifols', '#GS', '#GuggenheimPartnersLLC', '#NYSESlice', '#HexagonResources', '#HighwoodsProperties', '#i3Energy', '#IDG', '#Salmat', '#CNBCClassic', '#Intel', '#Intertek', '#JarvisSecurities', '#Jatenergy', '#KarelianDiamondResources', '#L1LongShortFund', '#LatrobeMagnesium', '#LHV', '#LithiumConsolidated', '#LowBonar', '#Macquarie', '#MagmaticResources', '#McDonalds', '#MECResources', '#MedAdvisor', '#MeritMedical', '#MetalBank', '#Metminco', '#MICROmega', '#HoloLens2', '#MinshengEducation', '#AustralianMines', '#MongoDB', '#NanoViricides', '#NationalPrestoIndustries', '#NewSports', '#Nomura', '#Nordstrom', '#NorthropGrumman', '#NovoNordisk', '#NOVONIX', '#Naspers', '#NuOilandGas', '#OceanGrownAbalone', '#OceanWilsons', '#OiSA', '#OPG', '#Orsted', '#PacificStarNetwork', '#PagSeguroDigital', '#PersonalAssetsTrust', '#Petratherm', '#PharmaronBeijing', '#PingAnSecurities', '#PioneerResources', '#PORR', '#PowerhouseVentures', '#PowerlongRealEstate', '#ProPacPackaging', '#ProsusNV', '#RealGoldMining', '#RedHillIron', '#RenascorResources', '#Renault', '#Renishaw', '#ResAppHealth', '#ChinaJishan', '#Ridley', '#RonsonDevelopment', '#RoyalDutchShell', '#SantanaMinerals', '#Sappi', '#SGS', '#ShelfDrilling', '#ShreeMinerals', '#SiennaCancerDiagnostics', '#SIIC', '#SinoHarbour', '#Skanska', '#Skyworks', '#Sophos', '#SorrentoTherapeutics', '#Southern', '#ES_F', '#StandardLifeAberdeen', '#StrideProperty', '#TaiwanFund', '#TelixPharmaceuticals', '#TernaSpA', '#TFFPharmaceuticals', '#ThomsonResources', '#Twitter', '#TysonFoods', '#UberTechnologies', '#Verseon', '#VistaOutdoor', '#WaterOasis', '#WeebitNano', '#WestpacBanking', '#WHSmith', '#Wincanton', '#XPS', '#YestarHealthcare', '#ZeldaTherapeutics', '#ZijinMining', '#Finablr', '#ArdaghSA', '#ATT', '#BankIndonesia', '#CastorMaritime', '#KeurigDrPepper', '#LondonStockExchange', '#SberbankRossii', '#WalgreensBootsAlliance', '#GFTTechnologies', '#AcornCapitalInvestmentFund', '#ArkRestaurants', '#CinerResourcesLP', '#CommonwealthBankofAustralia', '#HavilahResources', '#RingCentral', '#earnings', '#NYMEX', '#CNOOC', '#oil', '#WTI', '#LiquefiedNaturalGas', '#IAEA', '#CanadianPacificRailway', '#crudeoil', '#matprem', '#EEX', '#AkerBP', '#OilSearch', '#WorldCoalAssociation', '#Oil', '#coronavirus', '#emergingmarkets', '#index', '#ESG', '#FlashbackFriday', '#Seattle', '#throwba ...

# %% [markdown]
# ### Emojis

# %%
has_any_emoji = train_df["text"].apply(lambda x: bool(emoji.emoji_list(str(x)))).any()

if has_any_emoji:
  print(f"There are emojis in the dataset:")

  # Create a copy with only the rows that contain emojis
  train_df_emojis = train_df[train_df["text"].apply(lambda x: bool(emoji.emoji_list(str(x))))].copy()

  # Optionally add a column to show extracted emojis
  train_df_emojis["emojis"] = train_df_emojis["text"].apply(lambda x: [d["emoji"] for d in emoji.emoji_list(str(x))])

  # Preview
  print(train_df_emojis[["text", "emojis"]].head())

  percent = len(train_df_emojis) / len(train_df) * 100
  print(f"\nPercentage of tweets with emojis: {percent:.2f}%")
# Out:
# There are emojis in the dataset:
#                                                    text emojis
# 451   eib: #MustRead➡️EIB Bank Lending #Survey for #...   [➡️]
# 622   LIVE: Fed Chair Jerome Powell speaks on today'...   [▶️]
# 993     Invora™ Herbicide Receives EPA Federal Approval    [™]
# 1261  Applied DNA Announces Issuance of U.S. Patent ...    [®]
# 1350   Carvana Brings The New Way to Buy a Car™ to Utah    [™]
#
# Percentage of tweets with emojis: 0.56%

# %%
def apply_demojize(df, text_col='text'):
    df[text_col] = df[text_col].apply(lambda x: emoji.demojize(str(x)))
    return df

# %%
train_df_demojized = train_df.copy()

apply_demojize(train_df_demojized)
# Out:
#                                                    text  label
# 0     $BYND - JPMorgan reels in expectations on Beyo...      0
# 1     $CCL $RCL - Nomura points to bookings weakness...      0
# 2     $CX - Cemex cut at Credit Suisse, J.P. Morgan ...      0
# 3     $ESS: BTIG Research cuts to Neutral https://t....      0
# 4     $FNKO - Funko slides after Piper Jaffray PT cu...      0
# ...                                                 ...    ...
# 9538  The Week's Gainers and Losers on the Stoxx Eur...      2
# 9539  Tupperware Brands among consumer gainers; Unil...      2
# 9540  vTv Therapeutics leads healthcare gainers; Myo...      2
# 9541    WORK, XPO, PYX and AMKR among after hour movers      2
# 9542             YNDX, I, QD and OESX among tech movers      2
#
# [9543 rows x 2 columns]

# %%
demojize_pattern = re.compile(r":([a-zA-Z0-9_]+):")

def get_demojize(text):
    return [match.group(0) for match in demojize_pattern.finditer(str(text))]

demojized = train_df_demojized["text"].apply(get_demojize).explode().dropna().unique().tolist()

print("Demogized found:")
print(demojized)
# Out:
# Demogized found:
# [':right_arrow:', ':play_button:', ':trade_mark:', ':registered:', ':avocado:', ':copyright:', ':high_voltage:', ':sun:', ':snowflake:', ':school:', ':transgender_symbol:', ':Christmas_tree:', ':thinking_face:', ':check_mark_button:', ':palm_tree:', ':chart_increasing:', ':thumbs_up:', ':flushed_face:', ':female_sign:', ':turtle:', ':black_small_square:', ':musical_notes:', ':Chile:', ':North_Korea:', ':microphone:', ':newspaper:', ':headphone:', ':racing_car:', ':national_park:', ':mobile_phone:', ':face_with_medical_mask:', ':recycling_symbol:', ':bell:', ':up_arrow:', ':counterclockwise_arrows_button:', ':United_States:', ':grinning_face:', ':eyes:', ':waving_hand:']

# %%
has_any_emoji = train_df_demojized["text"].apply(lambda x: bool(emoji.emoji_list(str(x)))).any()

print(has_any_emoji)
# Out:
# False

# %% [markdown]
# ### Languages

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"
    
train_df['language'] = train_df['text'].apply(detect_language)

# %%
train_df['language'].unique()
# Out:
# array(['en', 'da', 'de', 'af', 'sv', 'no', 'ca', 'fr', 'et', 'es', 'nl',
#        'pt', 'tl', 'so', 'fi', 'pl', 'it', 'zh-cn', 'ro', 'id', 'unknown',
#        'hu', 'sl', 'cy', 'cs', 'vi', 'lt', 'sk', 'ja', 'sw', 'sq'],
#       dtype=object)

# %%
print(train_df['language'].value_counts())
# Out:
# language
# en         8854
# ca          114
# de          109
# es           89
# fr           86
# sv           62
# da           44
# no           28
# it           27
# nl           24
# af           20
# pt           13
# et           10
# tl           10
# ro            9
# id            8
# pl            8
# vi            5
# unknown       4
# so            3
# sl            3
# fi            2
# hu            2
# cy            2
# zh-cn         1
# cs            1
# lt            1
# sk            1
# ja            1
# sw            1
# sq            1
# Name: count, dtype: int64
